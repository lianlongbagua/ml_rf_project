# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cls_enterpos_training_specs.csv")

# %%
df.set_index('rank_test_score', drop=True, inplace=True)

# %%
# sort df by rank
df = df.sort_values(by=["mean_test_score"], ascending=True)

# %%
df['mean_test_score'].hist(bins=20)
# Out:
# <AxesSubplot:>
